# %% [markdown]
# 0. Load Data

# %%
import pandas as pd

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_json('csm.json')
df.head()
# Out:
#       id accession_number share_license_status  \
# 0  74228         2020.113                  CC0
# 1  74539         2015.449                  CC0
# 2  74540         2015.451                  CC0
# 3  74551        2018.1059                  CC0
# 4  74553        2018.1060                  CC0
#
#                                            tombstone current_location  \
# 0  Fishmarket, 1902. Camille Pissarro (French, 18...             None
# 1  A Miller's Carriage, c. 1895. Albert-Charles L...             None
# 2  Leda and the Swan, c. 1846–83. Adolphe Yvon (F...             None
# 3  The Monks, c. 1802–30. François Marius Granet ...             None
# 4  Study Sheet, c. 1870–80. Alfred Dehodencq (Fre...             None
#
#                  title title_in_original_language series  \
# 0           Fishmarket                       None   None
# 1  A Miller's Carriage                       None   None
# 2    Leda and the Swan                       None   None
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68076 entries, 0 to 68075
# Data columns (total 44 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           68076 non-null  int64
#  1   accession_number             68076 non-null  object
#  2   share_license_status         68076 non-null  object
#  3   tombstone                    68076 non-null  object
#  4   current_location             4244 non-null   object
#  5   title                        68076 non-null  object
#  6   title_in_original_language   1983 non-null   object
#  7   series                       4835 non-null   object
#  8   series_in_original_language  190 non-null    object
#  9   creation_date                66350 non-null  object
#  10  creation_date_earliest       66282 non-null  float64
#  11  creation_date_latest         66165 non-null  float64
#  12  artists_tags                 68076 non-null  object
# ...

# %%
# extract around 5000 from the dataset
sample = df.iloc[:5000]
sample
# Out:
#          id accession_number share_license_status  \
# 0     74228         2020.113                  CC0
# 1     74539         2015.449                  CC0
# 2     74540         2015.451                  CC0
# 3     74551        2018.1059                  CC0
# 4     74553        2018.1060                  CC0
# ...     ...              ...                  ...
# 4995  99131         1918.736                  CC0
# 4996  99132         1918.737                  CC0
# 4997  99133         1918.738                  CC0
# 4998  99134         1918.739                  CC0
# 4999  99136         1918.740                  CC0
#
#                                               tombstone current_location  \
# 0     Fishmarket, 1902. Camille Pissarro (French, 18...             None
# 1     A Miller's Carriage, c. 1895. Albert-Charles L...             None
# 2     Leda and the Swan, c. 1846–83. Adolphe Yvon (F...             None
# ...

# %%
# attributes selection
selected = sample[['title','creation_date','url','images','creators']]
selected
# Out:
#                     title creation_date  \
# 0              Fishmarket          1902
# 1     A Miller's Carriage       c. 1895
# 2       Leda and the Swan    c. 1846–83
# 3               The Monks    c. 1802–30
# 4             Study Sheet    c. 1870–80
# ...                   ...           ...
# 4995          Arrow Point         1700s
# 4996          Arrow Point         1700s
# 4997          Arrow Point         1700s
# 4998          Arrow Point         1700s
# 4999          Arrow Point         1700s
#
#                                          url  \
# 0      https://clevelandart.org/art/2020.113
# 1      https://clevelandart.org/art/2015.449
# 2      https://clevelandart.org/art/2015.451
# 3     https://clevelandart.org/art/2018.1059
# 4     https://clevelandart.org/art/2018.1060
# ...                                      ...
# 4995   https://clevelandart.org/art/1918.736
# 4996   https://clevelandart.org/art/1918.737
# 4997   https://clevelandart.org/art/1918.738
# ...

# %%
selected.to_csv("cma_5000.csv", index=False, encoding="utf-8")
print("Saved as cma_5000.csv")
# Out:
# Saved as cma_5000.csv

# %%
for item in selected['creators']:
    print (item)
    #print (type(item))
# Out:
# [{'id': 1836, 'description': 'Camille Pissarro (French, 1830–1903)', 'extent': None, 'qualifier': None, 'role': 'artist', 'biography': 'Camille Pissarro\'s parents ran a general merchandise business on St. Thomas. After attending boarding school in Paris, Pissarro returned to the West Indies to work for his father from 1847 until 1852. As an artist he was largely self-taught, receiving some instruction from Fritz Melbye (1826-1896), a Danish artist with whom he traveled to Venezuela in 1852. When Pissarro returned to Paris in 1855, he shared a studio with Anton Melbye (1818-1875), Fritz\'s brother, and with David Jacobsen (1821-1871). He took classes at the École des Beaux-Arts in 1856 and three years later attended the Académie Suisse, where he befriended artists such as Cézanne (q.v.), Monet (q.v.), and Guillaumin (q.v.). Corot (q.v.) encouraged him to paint landscapes around Paris, and he was listed as Corot\'s pupil in the catalogues of the Salons of 1864 and 1865. He had met Jul
# ...

# %%
pip install rdflib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import rdflib
from rdflib import Graph
from rdflib.namespace import RDF, RDFS
from rdflib import Namespace
import requests
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
import requests

# %% [markdown]
# 1. Artifact Representation

# %%
class Artifact:
    def __init__(self, data):
        self.title = data['title']
        self.date = data['creation_date']
        self.url = data['url']
        self.creators = [c['description'] for c in data['creators'] if 'description' in c]  # Extract only 'description' within the 'creators' attribute

    def __str__(self): # string representation
        return f"title: {self.title}\n creators:{self.creators}"

    def to_rdf(self):

        EX = Namespace("http://w3id.org/example/")
        CRM = Namespace("http://www.cidoc-crm.org/cidoc-crm/")
        DC = Namespace("http://purl.org/dc/elements/1.1/")

        graph = rdflib.Graph()

        graph.bind("ex", EX)
        graph.bind("crm", CRM)
        graph.bind("dc", DC)

        artifact_uri = rdflib.URIRef(f"http://example.org/artifact/{self.title.replace(' ', '_')}")

        # Add triples to the graph
        graph.add((artifact_uri, rdflib.RDF.type, rdflib.URIRef("http://example.org/Artifact"))) 
        graph.add((artifact_uri, rdflib.URIRef("http://example.org/title"), rdflib.Literal(self.title)))
        graph.add((artifact_uri, rdflib.URIRef("http://example.org/creation_date"), rdflib.Literal(self.date)))
        graph.add((artifact_uri, rdflib.URIRef("http://example.org/url"), rdflib.Literal(self.url)))
        
        for creator in self.creators:
            creator_uri = rdflib.URIRef(f"http://example.org/creator/{creator.replace(' ', '_')}")
            graph.add((artifact_uri, rdflib.URIRef("http://example.org/creator"), creator_uri))
            graph.add((creator_uri, rdflib.RDF.type, rdflib.URIRef("http://example.org/Creator")))
            graph.add((creator_uri, rdflib.URIRef("http://example.org/name"), rdflib.Literal(creator)))

        return graph

    def similar_wikidata_enrich(self):
        sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
    
        safe_title = self.title.replace('"', '\\"')  # Error handling for HTTP errors
        
        query = f"""
        SELECT ?item ?itemLabel
        WHERE {{
        # ?item wdt:P31 wd:Q3305213;  # Instance of artwork
                rdfs:label ?itemLabel.
        FILTER(LANG(?itemLabel) = "en")
        FILTER(CONTAINS(LCASE(?itemLabel), LCASE("{safe_title}")))
        }}
        LIMIT 5
        """

        sparql.setQuery(query)
        sparql.setReturnFormat(JSON)
        results = sparql.query().convert()

        enrich = [result["itemLabel"]["value"] for result in results["results"]["bindings"]]
        return enrich


    def artworks(self):
        # query both Chicago or Cleveland API for similar artworks
        chicago_api_url = f"https://api.artic.edu/api/v1/artworks/search?q={self.title}"
        response = requests.get(chicago_api_url)
        data = response.json()

        # Extract artwork information
        similar_artworks = []
        for artwork in data['data']:
            print(artwork)
            artwork_title = artwork['title']
            #artwork_creator = artwork['artist_display']
            #similar_artworks.append({"title": artwork_title})#, "creator": artwork_creator})
            similar_artworks.append(artwork_title)

        return similar_artworks

# %%
# Function test of the sample object "a"    
a = Artifact(selected.iloc[0]) 
print(a)

graph = a.to_rdf()
graph.print()

similar = a.similar_wikidata_enrich()
print(similar)

artworks = a.artworks()
print(artworks)
# Out:
# title: Fishmarket
#  creators:['Camille Pissarro (French, 1830–1903)']
# @prefix ns1: <http://example.org/> .
#
# <http://example.org/artifact/Fishmarket> a ns1:Artifact ;
#     ns1:creation_date "1902" ;
#     ns1:creator <http://example.org/creator/Camille_Pissarro_(French,_1830–1903)> ;
#     ns1:title "Fishmarket" ;
#     ns1:url "https://clevelandart.org/art/2020.113" .
#
# <http://example.org/creator/Camille_Pissarro_(French,_1830–1903)> a ns1:Creator ;
#     ns1:name "Camille Pissarro (French, 1830–1903)" .
# ['Fishmarket, Dieppe', 'Fishmarket', 'The Old Fishmarket, Norwich', 'The Fishmarket', 'The Fishmarket in Utrecht seen from Stadhuisbrug']
# ...

# %% [markdown]
# 2. Artist Representation, 1: N, one-to-many relationship

# %%
from rdflib import Graph, URIRef, Literal
from rdflib.namespace import RDFS, XSD
from rdflib.namespace import DC, DCTERMS, DOAP, FOAF, SKOS, OWL, RDF, RDFS, VOID, XMLNS, XSD

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
import requests

# %%
class Artist:
    def __init__(self,creator):

        #print(creator['description'])
        line = creator['description']
        tokens = line.split("(")  
        name = tokens[0].strip()
        nationality = "Not Found"
        if len(tokens)>1:
            tmp = tokens[1]
            tmp2 = tmp.split(",")
            nationality = tmp2[0].strip()
        self.name = name
        self.nationality = nationality
        self.artifacts = []  
    def __str__(self):
        return f"{self.name}"

    # simplistic proof of concept
    def to_rdf(self):
        EX = Namespace("http://example.org/")
        g = Graph()
        g.bind("ex", EX)
        g.bind("foaf", FOAF)

        artist_uri = URIRef(f"http://example.org/creator/{self.name.replace(' ', '_')}")

        g.add((artist_uri, RDF.type, EX.Creator))
        g.add((artist_uri, FOAF.name, Literal(self.name)))
        g.add((artist_uri, EX.nationality, Literal(self.nationality)))

        # struture artist-artifacts relationship 
        for title in self.artifacts:
            artifact_uri = URIRef(f"http://example.org/artifact/{title.replace(' ', '_')}")
            g.add((artifact_uri, RDF.type, EX.Artifact))
            g.add((artist_uri, EX.creatorOf, artifact_uri))
            g.add((artifact_uri, EX.title, Literal(title)))

        return g


def wikidata_enrichment(self):
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

    safe_name = self.name.replace('"', '\\"')

    # wiki query to find e.g. the artist's genre
    query = f"""
    SELECT ?genre ?genreLabel
    WHERE {{
        # ?artist rdfs:label "{safe_name}"@en;  # Search for artist by name
                wdt:P31 wd:Q5.  # Instance of human (artist)
        # ?artist wdt:P136 ?genre.  # Artist's genre (P136)
        # ?genre rdfs:label ?genreLabel.  # Genre's label
        FILTER(LANG(?genreLabel) = "en")
    }}
    LIMIT 1
    """

    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()

    if results["results"]["bindings"]:
        # Extract the genre label
        genre = results["results"]["bindings"][0]["genreLabel"]["value"]
        self.genre = genre  # Enrich artist with the genre
        return genre
    else:
        return None

# %%
# Information extraction from the "creators" attribute
for item in selected['creators']:
    for creator in item:
        # call the function
        artist = Artist(creator)
        artist.to_rdf()
        print(artist)
# Out:
# Camille Pissarro
# Albert-Charles Lebourg
# Adolphe Yvon
# François Marius Granet
# Alfred Dehodencq
# Auguste Raffet
# Louis Rolland Trinquesse
# Henri Joseph Harpignies
# Julien Léopold Boilly
# Mariano Fortuny
# Henri Lehmann
# Henri Lehmann
# Isidore Pils
# Louis-Nicolas van Blarenberghe
# Jean Louis Forain
# Jean Baptiste Martin, Le Vieux
# Giovanni Battista Cipriani
# Narcisse Berchère
# Eugène Delacroix
# Paul Delaroche
# Alexandre-Evariste Fragonard
# Louis Nicolas van Blarenberghe
# Victor Emile Prouvé
# V. Germain
# Eugène Cicéri
# Jules Joseph Augustin Laurens
# Constant Troyon
# Jules Dupré
# François-André Vincent
# Louis Félix de La Rue
# Alexandre-Evariste Fragonard
# Alexandre Bida
# Isidore Pils
# Gustave Doré
# Auguste Louis Lepère
# Gustave Doré
# Isidore Pils
# Isidore Pils
# Nicolas Toussaint Charlet
# Célestin François Nanteuil
# House of Fabergé
# House of Fabergé
# Henrik Wigström
# House of Fabergé
# John Sloan
# Ada Gilmore Chaffee
# Arthur Wesley Dow
# ...

# %% [markdown]
# 3. Collection group of Artifact

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install networkx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import rdflib
from rdflib import Graph, Literal, RDF, URIRef, Namespace
from rdflib.namespace import RDFS
import matplotlib.pyplot as plt
from collections import Counter
import requests
import os

# week 5 Übung
# create a namespace object
CRM = Namespace("http://www.cidoc-crm.org/cidoc-crm/") #CRM is an ontology used in museums, archives and CH institutions to describe objects, events and people and their relation
DC = Namespace("http://purl.org/dc/elements/1.1/") # for simple metadata like title, name 
EX = Namespace("http://w3id.org/example/") #custom namespace

class Collection:
    def __init__(self):
        self.artifacts = []
        self.artists = {}

    def add_artifact(self, artifact):
        self.artifacts.append(artifact)
        if artifact.artist and artifact.artist.name not in self.artists:
            self.add_artist(artifact.artist)

    def add_artist(self, artist):
        self.artists[artist.name] = artist

    
    def to_rdf(self, output_path="RDF_outputs/collection.ttl"):

        g = Graph()
    
        g.bind("crm", CRM)
        g.bind("dc", DC)
        g.bind("ex", EX)
        g.bind("rdfs", Namespace("http://www.w3.org/2000/01/rdf-schema#"))

        for artifact in self.artifacts:
            artifact_uri = EX[f"artifact{artifact.id:03d}"]
            artist_uri = EX[f"artist{artifact.id:03d}"]
            museum_uri = EX[f"museum{artifact.id:03d}"]

    # Add triples for the Artifact
            g.add((artifact_uri, RDF.type, CRM["E22_Man-Made_Object"]))
            g.add((artifact_uri, DC.title, Literal(artifact.title)))
            g.add((artifact_uri, DC.creator, artist_uri))
        
            if artifact.museum:
                # Link artifact to the current museum / place
                g.add((artifact_uri, CRM["P55_has_current_location"], museum_uri))
        
    # Add triples for the Artist
            g.add((artist_uri, RDF.type, CRM["E21_Person"]))
            g.add((artist_uri, RDFS.label, Literal(artifact.artist.name)))

    # Add triples for the Museum if present
            g.add((museum_uri, RDF.type, CRM["E53_Place"]))
            g.add((museum_uri, RDFS.label, Literal(artifact.museum)))

        os.makedirs(os.path.dirname(output_path), exist_ok=True)
        g.serialize(destination=output_path, format="turtle") # serialize the graph to Turtle ttl format
        print(f" RDF file was created: {output_path}")
        return g

    def visualize_metadata(self): 
        artist_counts = Counter([artifact.artist.name for artifact in self.artifacts if artifact.artist])

        artists = list(artist_counts.keys())
        counts = list(artist_counts.values())

        plt.figure(figsize=(8, 5))
        plt.bar(artists, counts, color='skyblue') # visualize it in bar chart
        plt.xlabel("Artists")
        plt.ylabel("Number of Artifacts")
        plt.title("Number of Artifacts per Artist")
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()
        plt.show()

    def visualize_rdf(self):
        import networkx as nx

        g = self.to_rdf()
        nx_graph = nx.DiGraph()

        for s, p, o in g:
            nx_graph.add_edge(str(s), str(o), label=str(p))

        pos = nx.spring_layout(nx_graph)
        plt.figure(figsize=(10, 8))
        nx.draw(nx_graph, pos, with_labels=True, node_size=2000, node_color="lightblue", arrows=True)
        edge_labels = nx.get_edge_attributes(nx_graph, 'label')
        nx.draw_networkx_edge_labels(nx_graph, pos, edge_labels=edge_labels)
        plt.title("RDF Graph representation")
        plt.show()

    def cross_api_enrich(self):
        #Enriches collection by fetching additional works by existing artists from Chicago AIC and Cleveland APIs
        base_aic = "https://api.artic.edu/api/v1/artworks/search"
        base_cleveland = "https://openaccess-api.clevelandart.org/api/artworks/"

        for artist_name in self.artists.keys():
            # AIC API
            params = {"q": artist_name, "limit": 3}
            aic_response = requests.get(base_aic, params=params).json()
            if "data" in aic_response:
                for item in aic_response["data"]:
                    artifact = Artifact(
                        id=f"aic_{item['id']}",
                        title=item.get("title", "Untitled"),
                        year=item.get("date_display", None),
                        artist=self.artists[artist_name]
                    )
                    self.add_artifact(artifact)

            # Cleveland API
            cleveland_response = requests.get(base_cleveland, params={"artist": artist_name, "limit": 3}).json()
            if "data" in cleveland_response:
                for item in cleveland_response["data"]:
                    artifact = Artifact(
                        id=f"cleveland_{item['id']}",
                        title=item.get("title", "Untitled"),
                        year=item.get("creation_date", None),
                        artist=self.artists[artist_name]
                    )
                    self.add_artifact(artifact)


# minimal Artifact and Artist classes
class Artist:
    def __init__(self, name, birth_year=None):
        self.name = name
        self.birth_year = birth_year


class Artifact:
    def __init__(self, id, title, year=None, artist=None, museum=None):
        self.id = id
        self.title = title
        self.year = year
        self.artist = artist
        self.museum = museum


collection = Collection() # erzeugt ein Objekt ,,collection" to the ,,Collection" class

for i in range(1, 51):
    artist = Artist(name=f"Artist {i}", birth_year=1800 + i)
    artifact = Artifact(
        id=i,
        title=f"Artifact number {i}",
        year=1900 + i,
        artist=artist,
        museum=f"Museum {i}"
    )
    collection.add_artifact(artifact)

# Generate RDF and save
collection.to_rdf()
# Out:
#  RDF file was created: RDF_outputs/collection.ttl
# <Graph identifier=N32e3ba6dba864fce8c30c37ee132691b (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# **4. Machine learning integration**

# %% [markdown]
# 4.1 Text-based, missing classification predication

# %%
import os
import csv
import requests
from tqdm import tqdm

OUTPUT_FILE = "aic_text_5000.csv"
FIELDS = ["id", "title", "artist_title", "classification_titles"]
API_URL = "https://api.artic.edu/api/v1/artworks"

def fetch_metadata(total=5000, per_page=100):
    results = []
    page = 1
    while len(results) < total:
        params = {
            "page": page,
            "limit": per_page,
            "fields": ",".join(FIELDS)
        }
        resp = requests.get(API_URL, params=params)
        if resp.status_code != 200:
            break
        data = resp.json().get("data", [])
        for item in data:
            # Skip entries when no artist/title found
            if not item.get("title") or not item.get("artist_title"):
                continue
            results.append({
                "id": item.get("id"),
                "title": item.get("title"),
                "artist_title": item.get("artist_title"),
                "classification_titles": ";".join(item.get("classification_titles", []))
            })
            if len(results) >= total:
                break
        page += 1
    return results

def save_to_csv(data, filename):
    with open(filename, "w", newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=data[0].keys())
        writer.writeheader()
        writer.writerows(data)

if __name__ == "__main__":
    data = fetch_metadata()
    save_to_csv(data, OUTPUT_FILE)
    print(f"Saved {len(data)} artworks to {OUTPUT_FILE}")
# Out:
# Saved 5000 artworks to aic_text_5000.csv

# %%
pip install wordcloud matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

df = pd.read_csv("aic_text_5000.csv")

# join all the classification strings into large string
all_classifications = df['classification_titles'].dropna().astype(str).str.cat(sep=';')
classifications_list = all_classifications.split(';')

# Create a frequency dictionary
freq_dict = {}
for cls in classifications_list:
    cls = cls.strip()
    if cls:
        freq_dict[cls] = freq_dict.get(cls, 0) + 1

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(freq_dict)

# Plot the word cloud
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Frequent Classification Titles')
plt.show()

# %% [markdown]
# Topic modelling to classification labels

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation #LDA model calculates how important each word is for a topic

df = pd.read_csv("aic_text_5000.csv")

texts = df['classification_titles'].fillna("")

# Vectorize titles (bag of words)
vectorizer = CountVectorizer(stop_words='english', max_features=1000)
X = vectorizer.fit_transform(texts)

# Train LDA to find first 5 topics
lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(X)

# Show top words per topic
def print_topics(model, feature_names, n_top_words):
    for idx, topic in enumerate(model.components_):
        print(f"Topic {idx + 1}:")
        print(", ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]))

print_topics(lda, vectorizer.get_feature_names_out(), 10)
# Out:
# Topic 1:
# arts, decorative, art, american, painting, modern, contemporary, vessel, european, silver
# Topic 2:
# painting, photograph, photography, oil, textile, weaving, paint, european, french, canvas
# Topic 3:
# drawing, drawings, visual, prints, works, architectural, architecture, paper, ink, design
# Topic 4:
# print, art, woodblock, asian, ancient, sculpture, glass, media, mixed, vessel
# Topic 5:
# print, prints, drawing, lithograph, etching, paper, transfer, woodcut, screenprint, book

# %% [markdown]
# **Cross Museum Artwork Title Clustering**

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans

# %%
# Merge datasets
aic = pd.read_csv("aic_text_5000.csv")
cma = pd.read_csv("cma_5000.csv")
df = pd.concat([aic, cma], ignore_index=True)

# %%
pip install "numpy<2"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
model = SentenceTransformer('all-MiniLM-L6-v2') #https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2

titles = df['title'].astype(str).tolist()
title_embeddings = model.encode(titles, show_progress_bar=True)
# Out:
# Batches: 100%|██████████| 313/313 [01:35<00:00,  3.29it/s]

# %%
num_clusters = 20  # cluster 20
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
clusters = kmeans.fit_predict(title_embeddings)
df['cluster'] = clusters

# %%
print(df.groupby("cluster")["title"].apply(lambda x: x.head(3)))
# Out:
# cluster
# 0        4                                      Seated Female Nude
#          85                                           Bronze Chair
#          109                                        Aluminum Chair
# 1        113                                    Untitled (Check 2)
#          118                                              Untitled
#          119                                              Untitled
# 2        249                      The Elements (Furnishing Fabric)
#          319               Gymnastics (Dress or Furnishing Fabric)
#          349                                           Sewing Desk
# 3        30                Saint Jerome Penitent in the Wilderness
#          37                              Saint Jerome in Penitence
#          39           Saint Jerome Reading in an Italian Landscape
# 4        20      Peonies and Butterfly, from an untitled series...
#          26      Precincts of Kameido Tenjin Shrine (Kameido Te...
# ...

# %%
pip install bertopic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.1 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.1/28.1 MB 6.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 10.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 8.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [bertopic]7/8 [bertopic]n]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bertopic import BERTopic #discover thematic “topics” from titles or descriptions.

topic_model = BERTopic(verbose=True)
topics, probs = topic_model.fit_transform(df["title"].tolist())

df["title"] = topics
topic_model.get_topic_info()  # Shows top words per title
# Out:
# 2025-07-21 16:20:52,803 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches: 100%|██████████| 313/313 [01:09<00:00,  4.49it/s]
# 2025-07-21 16:22:05,214 - BERTopic - Embedding - Completed ✓
# 2025-07-21 16:22:05,216 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-07-21 16:23:11,996 - BERTopic - Dimensionality - Completed ✓
# 2025-07-21 16:23:12,000 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-07-21 16:23:13,559 - BERTopic - Cluster - Completed ✓
# 2025-07-21 16:23:13,575 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-07-21 16:23:15,099 - BERTopic - Representation - Completed ✓
#      Topic  Count                                         Name  \
# 0       -1   1748                          -1_series_the_la_at
# 1        0    299                    0_untitled_demos_mr_still
# 2        1    174                     1_rome_views_view_temple
# ...

# %%
import umap
import matplotlib.pyplot as plt

reducer = umap.UMAP(n_neighbors=15, min_dist=0.1, random_state=42) #reduce dimension, adjust parameter
embedding_2d = reducer.fit_transform(title_embeddings)

plt.figure(figsize=(10,7))
plt.scatter(embedding_2d[:,0], embedding_2d[:,1], c=df["cluster"], cmap="tab20", s=5) # 0: take all rows, first column, 1: second column
plt.title("Artifact Title Clustering Chicago x Cleveland")
plt.show()

# %% [markdown]
# Close points = similar artworks/topics
# Far-apart points = different topics/styles

# %% [markdown]
# 4.2 Image-based

# %%
import os
import requests
from tqdm import tqdm #track the advancement of time-intensive tasks
import time

SAVE_DIR = "aic_images" #output path
os.makedirs(SAVE_DIR, exist_ok=True)

# AIC provides directly image API: https://api.artic.edu/docs/#iiif-image-api
BASE_API_URL = "https://api.artic.edu/api/v1/artworks"
BASE_IMAGE_URL = "https://www.artic.edu/iiif/2/{}/full/843,/0/default.jpg"  # READ the API documentation and Term of Use guideline 

LIMIT = 100           # Max images per API call
TOTAL_IMAGES = 5000   # 5000 as wishes but lets see :)
PAGES = TOTAL_IMAGES // LIMIT

downloaded = 0

print(f"Starting download... Saving to '{SAVE_DIR}'")

for page in range(1, PAGES + 1):
    url = f"{BASE_API_URL}?page={page}&limit={LIMIT}&fields=id,title,image_id"
    response = requests.get(url).json()

    artworks = response.get("data", [])
    
    for artwork in tqdm(artworks, desc=f"Page {page}/{PAGES}"):
        image_id = artwork.get("image_id")
        if not image_id:
            continue

        image_url = BASE_IMAGE_URL.format(image_id)
        filename = os.path.join(SAVE_DIR, f"{artwork['id']}.jpg")

        # Skip if already downloaded
        if os.path.exists(filename):
            continue

        try:
            img_data = requests.get(image_url, timeout=10)
            if img_data.status_code == 200:
                with open(filename, "wb") as f:
                    f.write(img_data.content)
                downloaded += 1
        except Exception as e:
            print(f"Failed: {artwork['id']} - {e}")

        if downloaded >= TOTAL_IMAGES:
            break

    print(f"✅Page {page} complete - Total downloaded so far: {downloaded}")
    time.sleep(3)  # Be polite to the API, avoid rate limits

print(f"\n ✅Download complete: {downloaded} images saved in '{SAVE_DIR}'")
# Out:
# Starting download... Saving to 'aic_images'
# Page 1/50: 100%|██████████| 100/100 [00:23<00:00,  4.17it/s]
# ✅ Page 1 complete - Total downloaded so far: 95
# Page 2/50: 100%|██████████| 100/100 [00:17<00:00,  5.63it/s]
# ✅ Page 2 complete - Total downloaded so far: 179
# Page 3/50: 100%|██████████| 100/100 [00:16<00:00,  6.19it/s]
# ✅ Page 3 complete - Total downloaded so far: 278
# Page 4/50: 100%|██████████| 100/100 [00:15<00:00,  6.63it/s]
# ✅ Page 4 complete - Total downloaded so far: 376
# Page 5/50: 100%|██████████| 100/100 [00:20<00:00,  4.88it/s]
# ✅ Page 5 complete - Total downloaded so far: 476
# Page 6/50: 100%|██████████| 100/100 [00:19<00:00,  5.02it/s]
# ✅ Page 6 complete - Total downloaded so far: 576
# Page 7/50: 100%|██████████| 100/100 [00:14<00:00,  6.81it/s]
# ✅ Page 7 complete - Total downloaded so far: 675
# Page 8/50: 100%|██████████| 100/100 [00:14<00:00,  6.75it/s]
# ✅ Page 8 complete - Total downloaded so far: 775
# ...

# %% [markdown]
# **Only get 1402 images from the image api, to get rid of crashing the whole problem, second try is not continued**

# %% [markdown]
# Not all artifact has images if the id is missing
